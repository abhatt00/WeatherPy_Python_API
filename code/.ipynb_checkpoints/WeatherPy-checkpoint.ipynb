# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
unites = "imperial"

query_url = f"{url}appid={api_key}&units&q="
print(query_url)

cityname = []
countryname = []
latitude = []
longitude = []
maxtemp = []
humidity = []
cloudiness = []
date = []
windspeed = []
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=59166562bfec44e3e627176a07991947&units&q=

# %%
count = 1

print(f"Beginning Data Retrieval")
print(f"-----------------------------")

for city in cities:
    
    try:

        if (count > 500):
            break
        response = requests.get(f"{query_url}{city}").json()
        cityname.append(response["name"])
        countryname.append(response["sys"]["country"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        maxtemp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        date.append(response["dt"])
        windspeed.append(response["wind"]["speed"])
        
        print(f"Processing data for City {count} ~ {city}")
        count += 1
        
        # wait for a second to avoid blocking the calls
        time.sleep(1.00)
        
    except:
        print(f"{city} not found, moving on!")
        
    continue
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing data for City 1 ~ jumla
# Processing data for City 2 ~ atuona
# Processing data for City 3 ~ arraial do cabo
# Processing data for City 4 ~ tuktoyaktuk
# Processing data for City 5 ~ busselton
# Processing data for City 6 ~ petropavlovsk-kamchatskiy
# Processing data for City 7 ~ souillac
# Processing data for City 8 ~ mataura
# bengkulu not found, moving on!
# Processing data for City 9 ~ kapaa
# Processing data for City 10 ~ new norfolk
# Processing data for City 11 ~ rikitea
# Processing data for City 12 ~ albany
# Processing data for City 13 ~ chuy
# Processing data for City 14 ~ cabo san lucas
# Processing data for City 15 ~ thompson
# Processing data for City 16 ~ shingu
# Processing data for City 17 ~ leningradskiy
# Processing data for City 18 ~ ribeira grande
# la gaulette not found, moving on!
# Processing data for City 19 ~ dakar
# Processing data for City 20 ~ maceio
# Processing data for City 21 ~ sobolevo
# grand river south east not found, moving on!
# Processing data for City 22 ~ pandrup
# Processing data for City 23 ~ bredasdorp
# Processing data for City 24 ~ mahebourg
# Processing data for City 25 ~ luwuk
# Processing data for City 26 ~ severo-kurilsk
# illoqqortoormiut not found, moving on!
# Processing data for City 27 ~ carnarvon
# Processing data for City 28 ~ torbay
# Processing data for City 29 ~ show low
# Processing data for City 30 ~ bluff
# Processing data for City 31 ~ hobart
# Processing data for City 32 ~ andapa
# Processing data for City 33 ~ saskylakh
# barentsburg not found, moving on!
# Processing data for City 34 ~ ylivieska
# Processing data for City 35 ~ cape town
# Processing data for City 36 ~ hambantota
# kuche not found, moving on!
# Processing data for City 37 ~ komsomolskiy
# Processing data for City 38 ~ khatanga
# Processing data for City 39 ~ aklavik
# belushya guba not found, moving on!
# henzada not found, moving on!
# Processing data for City 40 ~ la romana
# one hundred mile house not found, moving on!
# Processing data for City 41 ~ hovd
# taolanaro not found, moving on!
# Processing data for City 42 ~ usinsk
# Processing data for City 43 ~ butaritari
# Processing data for City 44 ~ iqaluit
# vaitupu not found, moving on!
# Processing data for City 45 ~ guerrero negro
# Processing data for City 46 ~ avarua
# Processing data for City 47 ~ tuy hoa
# Processing data for City 48 ~ jonuta
# Processing data for City 49 ~ north bend
# Processing data for City 50 ~ marshall
# Processing data for City 51 ~ narsaq
# Processing data for City 52 ~ ushuaia
# Processing data for City 53 ~ weligama
# Processing data for City 54 ~ adrar
# Processing data for City 55 ~ kaitangata
# sentyabrskiy not found, moving on!
# Processing data for City 56 ~ bethel
# Processing data for City 57 ~ codrington
# Processing data for City 58 ~ jamestown
# Processing data for City 59 ~ aljezur
# Processing data for City 60 ~ lebu
# Processing data for City 61 ~ puerto ayora
# Processing data for City 62 ~ abu zabad
# Processing data for City 63 ~ magaria
# Processing data for City 64 ~ faanui
# Processing data for City 65 ~ sao filipe
# Processing data for City 66 ~ hermanus
# Processing data for City 67 ~ portland
# Processing data for City 68 ~ leh
# Processing data for City 69 ~ qaanaaq
# Processing data for City 70 ~ saldanha
# Processing data for City 71 ~ bambous virieux
# Processing data for City 72 ~ whitecourt
# Processing data for City 73 ~ presidente medici
# Processing data for City 74 ~ punta arenas
# Processing data for City 75 ~ norman wells
# tabiauea not found, moving on!
# Processing data for City 76 ~ kamogawa
# Processing data for City 77 ~ dikson
# Processing data for City 78 ~ chokurdakh
# Processing data for City 79 ~ merauke
# Processing data for City 80 ~ les cayes
# kyra not found, moving on!
# Processing data for City 81 ~ nuuk
# Processing data for City 82 ~ arlit
# Processing data for City 83 ~ quatre cocos
# Processing data for City 84 ~ puerto baquerizo moreno
# tsihombe not found, moving on!
# Processing data for City 85 ~ kushima
# Processing data for City 86 ~ nikolskoye
# Processing data for City 87 ~ oranjemund
# Processing data for City 88 ~ goderich
# Processing data for City 89 ~ padang
# solsvik not found, moving on!
# Processing data for City 90 ~ victoria
# aflu not found, moving on!
# Processing data for City 91 ~ verkh-suetka
# Processing data for City 92 ~ chabahar
# Processing data for City 93 ~ paris
# Processing data for City 94 ~ tiksi
# Processing data for City 95 ~ newport
# Processing data for City 96 ~ margate
# Processing data for City 97 ~ lorengau
# tambura not found, moving on!
# Processing data for City 98 ~ vaini
# Processing data for City 99 ~ alice springs
# Processing data for City 100 ~ wanning
# Processing data for City 101 ~ prado
# Processing data for City 102 ~ port alfred
# meyungs not found, moving on!
# Processing data for City 103 ~ grand gaube
# Processing data for City 104 ~ tasiilaq
# Processing data for City 105 ~ ulagan
# Processing data for City 106 ~ zhigansk
# Processing data for City 107 ~ hilo
# Processing data for City 108 ~ conde
# Processing data for City 109 ~ tura
# Processing data for City 110 ~ kashary
# Processing data for City 111 ~ pekan
# Processing data for City 112 ~ saint-philippe
# Processing data for City 113 ~ bhan
# Processing data for City 114 ~ magalia
# satitoa not found, moving on!
# Processing data for City 115 ~ east london
# Processing data for City 116 ~ fairbanks
# Processing data for City 117 ~ sitka
# Processing data for City 118 ~ hasaki
# Processing data for City 119 ~ coachella
# Processing data for City 120 ~ plettenberg bay
# Processing data for City 121 ~ saint-georges
# Processing data for City 122 ~ zemio
# Processing data for City 123 ~ salalah
# Processing data for City 124 ~ coffs harbour
# Processing data for City 125 ~ isangel
# Processing data for City 126 ~ kasempa
# Processing data for City 127 ~ skelleftea
# grand centre not found, moving on!
# marcona not found, moving on!
# Processing data for City 128 ~ ahuimanu
# Processing data for City 129 ~ vardo
# Processing data for City 130 ~ cidreira
# mys shmidta not found, moving on!
# Processing data for City 131 ~ potosi
# pazardzik not found, moving on!
# Processing data for City 132 ~ vila franca do campo
# Processing data for City 133 ~ myitkyina
# Processing data for City 134 ~ ambilobe
# warqla not found, moving on!
# Processing data for City 135 ~ kavieng
# Processing data for City 136 ~ nelson
# Processing data for City 137 ~ lagoa
# Processing data for City 138 ~ naze
# Processing data for City 139 ~ owasso
# Processing data for City 140 ~ port elizabeth
# Processing data for City 141 ~ bani
# amderma not found, moving on!
# Processing data for City 142 ~ bonnyville
# Processing data for City 143 ~ batemans bay
# Processing data for City 144 ~ pestovo
# Processing data for City 145 ~ orlovo
# Processing data for City 146 ~ guymon
# Processing data for City 147 ~ saint anthony
# Processing data for City 148 ~ tucurui
# Processing data for City 149 ~ longyearbyen
# Processing data for City 150 ~ augusto correa
# Processing data for City 151 ~ ostrovnoy
# Processing data for City 152 ~ esperance
# Processing data for City 153 ~ lander
# Processing data for City 154 ~ mount gambier
# Processing data for City 155 ~ vostok
# Processing data for City 156 ~ lavrentiya
# Processing data for City 157 ~ kattivakkam
# Processing data for City 158 ~ yellowknife
# Processing data for City 159 ~ georgetown
# Processing data for City 160 ~ lata
# Processing data for City 161 ~ berlevag
# Processing data for City 162 ~ samarai
# atka not found, moving on!
# Processing data for City 163 ~ ponta do sol
# Processing data for City 164 ~ barrow
# Processing data for City 165 ~ praya
# Processing data for City 166 ~ lasa
# Processing data for City 167 ~ banepa
# Processing data for City 168 ~ phan thiet
# Processing data for City 169 ~ natal
# Processing data for City 170 ~ kimbe
# Processing data for City 171 ~ soto la marina
# Processing data for City 172 ~ shurob
# Processing data for City 173 ~ hwange
# Processing data for City 174 ~ leshukonskoye
# Processing data for City 175 ~ san quintin
# Processing data for City 176 ~ abbeville
# Processing data for City 177 ~ santa maria del oro
# Processing data for City 178 ~ flinders
# Processing data for City 179 ~ brae
# Processing data for City 180 ~ itoman
# Processing data for City 181 ~ imbituba
# Processing data for City 182 ~ machilipatnam
# Processing data for City 183 ~ san cristobal
# Processing data for City 184 ~ nouadhibou
# Processing data for City 185 ~ gizo
# Processing data for City 186 ~ bilibino
# Processing data for City 187 ~ cururupu
# Processing data for City 188 ~ tomatlan
# Processing data for City 189 ~ marquette
# Processing data for City 190 ~ muros
# Processing data for City 191 ~ tignere
# Processing data for City 192 ~ nelson bay
# Processing data for City 193 ~ sharlyk
# Processing data for City 194 ~ aksarka
# Processing data for City 195 ~ ivolginsk
# Processing data for City 196 ~ racale
# Processing data for City 197 ~ allapalli
# Processing data for City 198 ~ nanortalik
# Processing data for City 199 ~ luderitz
# Processing data for City 200 ~ rocha
# Processing data for City 201 ~ mount isa
# Processing data for City 202 ~ oga
# Processing data for City 203 ~ wajid
# Processing data for City 204 ~ salinopolis
# Processing data for City 205 ~ soyo
# Processing data for City 206 ~ katsuura
# Processing data for City 207 ~ kodiak
# Processing data for City 208 ~ monster
# Processing data for City 209 ~ quilmana
# Processing data for City 210 ~ borba
# Processing data for City 211 ~ eyl
# Processing data for City 212 ~ new brunswick
# Processing data for City 213 ~ eravur
# Processing data for City 214 ~ tabou
# Processing data for City 215 ~ clyde river
# Processing data for City 216 ~ bonthe
# Processing data for City 217 ~ airai
# Processing data for City 218 ~ ustye
# Processing data for City 219 ~ jackson
# attawapiskat not found, moving on!
# vestbygda not found, moving on!
# longlac not found, moving on!
# Processing data for City 220 ~ atar
# Processing data for City 221 ~ urusha
# Processing data for City 222 ~ roma
# Processing data for City 223 ~ mar del plata
# Processing data for City 224 ~ kendari
# Processing data for City 225 ~ pevek
# Processing data for City 226 ~ mehamn
# Processing data for City 227 ~ perehonivka
# Processing data for City 228 ~ sakaiminato
# Processing data for City 229 ~ dali
# Processing data for City 230 ~ ati
# Processing data for City 231 ~ dawlatabad
# Processing data for City 232 ~ castro
# Processing data for City 233 ~ camacha
# sataua not found, moving on!
# Processing data for City 234 ~ hithadhoo
# Processing data for City 235 ~ westport
# Processing data for City 236 ~ yulara
# Processing data for City 237 ~ touros
# Processing data for City 238 ~ patiya
# Processing data for City 239 ~ derzhavinsk
# Processing data for City 240 ~ avera
# Processing data for City 241 ~ vieste
# Processing data for City 242 ~ campos belos
# Processing data for City 243 ~ maniitsoq
# Processing data for City 244 ~ vestmannaeyjar
# Processing data for City 245 ~ koumac
# Processing data for City 246 ~ upernavik
# Processing data for City 247 ~ baker city
# Processing data for City 248 ~ dingle
# Processing data for City 249 ~ yar-sale
# Processing data for City 250 ~ north platte
# Processing data for City 251 ~ luau
# Processing data for City 252 ~ shakawe
# Processing data for City 253 ~ loralai
# Processing data for City 254 ~ methoni
# Processing data for City 255 ~ imeni poliny osipenko
# Processing data for City 256 ~ xai-xai
# Processing data for City 257 ~ laguna
# Processing data for City 258 ~ balkanabat
# Processing data for City 259 ~ fort nelson
# Processing data for City 260 ~ nantucket
# Processing data for City 261 ~ ust-nera
# muktagachha not found, moving on!
# Processing data for City 262 ~ nata
# Processing data for City 263 ~ isla vista
# Processing data for City 264 ~ moose factory
# zachagansk not found, moving on!
# Processing data for City 265 ~ putina
# nizhneyansk not found, moving on!
# Processing data for City 266 ~ chernyshevskiy
# Processing data for City 267 ~ sokolo
# Processing data for City 268 ~ bubaque
# Processing data for City 269 ~ geraldton
# Processing data for City 270 ~ simbahan
# Processing data for City 271 ~ jizan
# Processing data for City 272 ~ tuatapere
# Processing data for City 273 ~ ulladulla
# kachikau not found, moving on!
# Processing data for City 274 ~ jambi
# Processing data for City 275 ~ hudson bay
# Processing data for City 276 ~ meulaboh
# Processing data for City 277 ~ martapura
# Processing data for City 278 ~ zhezkazgan
# Processing data for City 279 ~ san policarpo
# Processing data for City 280 ~ boueni
# Processing data for City 281 ~ kokstad
# Processing data for City 282 ~ panama city
# Processing data for City 283 ~ rawson
# Processing data for City 284 ~ kuala terengganu
# Processing data for City 285 ~ prieska
# Processing data for City 286 ~ provideniya
# Processing data for City 287 ~ svolvaer
# Processing data for City 288 ~ kappeln
# Processing data for City 289 ~ honiara
# Processing data for City 290 ~ altamont
# Processing data for City 291 ~ sosva
# Processing data for City 292 ~ russell
# Processing data for City 293 ~ dalnerechensk
# Processing data for City 294 ~ chiredzi
# urumqi not found, moving on!
# Processing data for City 295 ~ oleksandrivka
# Processing data for City 296 ~ windsor
# Processing data for City 297 ~ aswan
# Processing data for City 298 ~ brigantine
# Processing data for City 299 ~ labuhan
# Processing data for City 300 ~ mlowo
# Processing data for City 301 ~ aksay
# Processing data for City 302 ~ yumen
# Processing data for City 303 ~ mae tha
# Processing data for City 304 ~ kaitong
# Processing data for City 305 ~ ramhormoz
# Processing data for City 306 ~ filingue
# raga not found, moving on!
# palabuhanratu not found, moving on!
# we not found, moving on!
# Processing data for City 307 ~ galesong
# Processing data for City 308 ~ astaneh-ye ashrafiyeh
# Processing data for City 309 ~ vieques
# Processing data for City 310 ~ kutum
# Processing data for City 311 ~ weihai
# krasnoselkup not found, moving on!
# Processing data for City 312 ~ ukiah
# andevoranto not found, moving on!
# Processing data for City 313 ~ oistins
# Processing data for City 314 ~ gerash
# Processing data for City 315 ~ tual
# kamenskoye not found, moving on!
# Processing data for City 316 ~ ampanihy
# Processing data for City 317 ~ luanda
# Processing data for City 318 ~ piotrkow trybunalski
# Processing data for City 319 ~ richards bay
# Processing data for City 320 ~ niquelandia
# tumannyy not found, moving on!
# Processing data for City 321 ~ salekhard
# Processing data for City 322 ~ saint-pierre
# Processing data for City 323 ~ mahibadhoo
# Processing data for City 324 ~ tanete
# Processing data for City 325 ~ egvekinot
# Processing data for City 326 ~ burnie
# Processing data for City 327 ~ sile
# Processing data for City 328 ~ baruun-urt
# Processing data for City 329 ~ ibra
# Processing data for City 330 ~ wuwei
# Processing data for City 331 ~ half moon bay
# kismayo not found, moving on!
# Processing data for City 332 ~ biak
# asau not found, moving on!
# Processing data for City 333 ~ ancud
# Processing data for City 334 ~ homer
# Processing data for City 335 ~ copiapo
# yirol not found, moving on!
# Processing data for City 336 ~ jijiang
# Processing data for City 337 ~ alofi
# Processing data for City 338 ~ lebyazhye
# Processing data for City 339 ~ sao jose da coroa grande
# Processing data for City 340 ~ weihe
# Processing data for City 341 ~ brokopondo
# Processing data for City 342 ~ seoul
# Processing data for City 343 ~ pisco
# Processing data for City 344 ~ palmer
# Processing data for City 345 ~ bonoua
# Processing data for City 346 ~ malanje
# Processing data for City 347 ~ necochea
# Processing data for City 348 ~ surajgarh
# Processing data for City 349 ~ bilma
# Processing data for City 350 ~ charagua
# Processing data for City 351 ~ moroni
# Processing data for City 352 ~ bathsheba
# Processing data for City 353 ~ constitucion
# Processing data for City 354 ~ havre
# moiyabana not found, moving on!
# Processing data for City 355 ~ oktyabrskiy
# Processing data for City 356 ~ zambezi
# Processing data for City 357 ~ mochudi
# Processing data for City 358 ~ altay
# Processing data for City 359 ~ saint george
# Processing data for City 360 ~ kruisfontein
# Processing data for City 361 ~ afyonkarahisar
# Processing data for City 362 ~ keuruu
# jomalig not found, moving on!
# Processing data for City 363 ~ inhambane
# Processing data for City 364 ~ hofn
# Processing data for City 365 ~ lingyuan
# Processing data for City 366 ~ davidson
# domoni not found, moving on!
# Processing data for City 367 ~ luganville
# Processing data for City 368 ~ ossora
# Processing data for City 369 ~ athabasca
# Processing data for City 370 ~ harrison
# Processing data for City 371 ~ vanavara
# Processing data for City 372 ~ talnakh
# Processing data for City 373 ~ qovlar
# Processing data for City 374 ~ luwingu
# Processing data for City 375 ~ lahad datu
# Processing data for City 376 ~ ghanzi
# Processing data for City 377 ~ grindavik
# Processing data for City 378 ~ cherskiy
# Processing data for City 379 ~ biryusinsk
# Processing data for City 380 ~ charters towers
# Processing data for City 381 ~ la ronge
# Processing data for City 382 ~ hami
# Processing data for City 383 ~ amposta
# Processing data for City 384 ~ poronaysk
# Processing data for City 385 ~ zyryanovsk
# Processing data for City 386 ~ douglas
# rawannawi not found, moving on!
# Processing data for City 387 ~ kualakapuas
# Processing data for City 388 ~ hanyang
# Processing data for City 389 ~ boa vista
# Processing data for City 390 ~ tamiahua
# gorno-chuyskiy not found, moving on!
# bajo baudo not found, moving on!
# Processing data for City 391 ~ alyangula
# Processing data for City 392 ~ burns lake
# Processing data for City 393 ~ tilichiki
# Processing data for City 394 ~ thinadhoo
# Processing data for City 395 ~ vesyegonsk
# Processing data for City 396 ~ alghero
# Processing data for City 397 ~ vigevano
# Processing data for City 398 ~ neyshabur
# Processing data for City 399 ~ taltal
# Processing data for City 400 ~ bastia
# Processing data for City 401 ~ paamiut
# Processing data for City 402 ~ porto belo
# Processing data for City 403 ~ salinas
# Processing data for City 404 ~ superior
# ascension not found, moving on!
# Processing data for City 405 ~ port barton
# Processing data for City 406 ~ vila do maio
# korla not found, moving on!
# Processing data for City 407 ~ rio grande
# Processing data for City 408 ~ santa isabel do rio negro
# Processing data for City 409 ~ tucumcari
# Processing data for City 410 ~ hailar
# Processing data for City 411 ~ jalu
# Processing data for City 412 ~ port hardy
# Processing data for City 413 ~ saint-augustin
# Processing data for City 414 ~ pandan
# Processing data for City 415 ~ ngunguru
# Processing data for City 416 ~ pelym
# Processing data for City 417 ~ puerto escondido
# Processing data for City 418 ~ kibala
# Processing data for City 419 ~ kalmunai
# viligili not found, moving on!
# ijaki not found, moving on!
# Processing data for City 420 ~ ponta delgada
# Processing data for City 421 ~ aguimes
# Processing data for City 422 ~ namatanai
# Processing data for City 423 ~ hartlepool
# Processing data for City 424 ~ hengyang
# Processing data for City 425 ~ bam
# Processing data for City 426 ~ axim
# Processing data for City 427 ~ luis correia
# Processing data for City 428 ~ ilulissat
# Processing data for City 429 ~ byron bay
# samusu not found, moving on!
# Processing data for City 430 ~ jinka
# Processing data for City 431 ~ gilgit
# Processing data for City 432 ~ karibib
# Processing data for City 433 ~ kysyl-syr
# chokwe not found, moving on!
# Processing data for City 434 ~ husavik
# Processing data for City 435 ~ mier
# Processing data for City 436 ~ winnemucca
# Processing data for City 437 ~ oswego
# Processing data for City 438 ~ coolum beach
# Processing data for City 439 ~ atasu
# Processing data for City 440 ~ ormara
# Processing data for City 441 ~ taoudenni
# Processing data for City 442 ~ iwanai
# Processing data for City 443 ~ aksha
# Processing data for City 444 ~ singaparna
# Processing data for City 445 ~ dicabisagan
# Processing data for City 446 ~ kieta
# Processing data for City 447 ~ caravelas
# bokoro not found, moving on!
# Processing data for City 448 ~ lishu
# Processing data for City 449 ~ druzhba
# Processing data for City 450 ~ palmares
# Processing data for City 451 ~ oyonnax
# Processing data for City 452 ~ kavaratti
# Processing data for City 453 ~ yatou
# Processing data for City 454 ~ fortuna
# Processing data for City 455 ~ watsa
# Processing data for City 456 ~ winona
# Processing data for City 457 ~ majene
# Processing data for City 458 ~ baijiantan
# qunduz not found, moving on!
# Processing data for City 459 ~ parczew
# Processing data for City 460 ~ acapulco
# Processing data for City 461 ~ lalmohan
# Processing data for City 462 ~ west fargo
# Processing data for City 463 ~ kijang
# Processing data for City 464 ~ port-gentil
# Processing data for City 465 ~ mandalgovi
# Processing data for City 466 ~ zelenogorskiy
# Processing data for City 467 ~ tateyama
# Processing data for City 468 ~ maningrida
# Processing data for City 469 ~ fuling
# Processing data for City 470 ~ guangshui
# Processing data for City 471 ~ klaksvik
# Processing data for City 472 ~ havre-saint-pierre
# Processing data for City 473 ~ beringovskiy
# Processing data for City 474 ~ vondrozo
# Processing data for City 475 ~ chicama
# Processing data for City 476 ~ novonikolayevskiy
# Processing data for City 477 ~ kadrina
# bairiki not found, moving on!
# Processing data for City 478 ~ bowen
# Processing data for City 479 ~ aspindza
# Processing data for City 480 ~ haimen
# Processing data for City 481 ~ horadiz
# Processing data for City 482 ~ ucluelet
# Processing data for City 483 ~ sao miguel do araguaia
# Processing data for City 484 ~ novomyrhorod
# olafsvik not found, moving on!
# Processing data for City 485 ~ haapiti
# Processing data for City 486 ~ uaua
# Processing data for City 487 ~ sistranda
# Processing data for City 488 ~ kasulu
# Processing data for City 489 ~ pozo colorado
# Processing data for City 490 ~ itarema
# Processing data for City 491 ~ champerico
# Processing data for City 492 ~ belawan
# Processing data for City 493 ~ tiverton
# Processing data for City 494 ~ parrita
# Processing data for City 495 ~ ahipara
# Processing data for City 496 ~ baiyin
# Processing data for City 497 ~ amarkantak
# Processing data for City 498 ~ coihaique
# Processing data for City 499 ~ zhangye
# Processing data for City 500 ~ andros

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather = {
    "City": cityname,
    "Cloudiness": cloudiness, 
    "Country": countryname,
    "Date": date, 
    "Humidity": humidity,
    "Latitude": latitude, 
    "Longitude": longitude, 
    "Max Temp": maxtemp,
    "Wind Speed":windspeed
}

weather_df = pd.DataFrame(weather)
weather_df.count()
# Out:
# City          500
# Cloudiness    500
# Country       500
# Date          500
# Humidity      500
# Latitude      500
# Longitude     500
# Max Temp      500
# Wind Speed    500
# dtype: int64

# %%
weather_df.to_csv(output_data_file)
weather_df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity  Latitude  \
# 0            Jumla          31      NP  1570084275        56     29.28
# 1           Atuona          12      PF  1570084007        76     -9.80
# 2  Arraial do Cabo           0      BR  1570084161        86    -22.97
# 3      Tuktoyaktuk          90      CA  1570084279       100     69.44
# 4        Busselton          87      AU  1570084123        32    -33.64
#
#    Longitude  Max Temp  Wind Speed
# 0      82.18   290.802        2.07
# 1    -139.03   299.612        4.78
# 2     -42.02   293.202        8.25
# 3    -133.03   275.150        5.10
# 4     115.35   298.710        4.60

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
