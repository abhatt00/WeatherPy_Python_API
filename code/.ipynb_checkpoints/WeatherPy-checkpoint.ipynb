# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key from a separate file
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV) to print list of cities used in API call
output_data_file = "output_data/cities.csv"
output_data_file_2nd = "output_data/cities_2.csv"

# Range of latitudes and longitudes
# All combinations of latitudes and longitudes being selected will come from between the following parameters
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations, we will get 1500 combinations of lat/lng coordinates.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
# numpy uses random to get a list of numbers for each list, 1500 for lat, 1500 for lng.
# lat_lngs is zipped together to make one list out of two
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
# for each combination in the list of lat_lng, use citipy to find the nearest city to the lat/lng location
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
#     citypy module is used to call out the city name for the list of lat/lng combinations

    # If the city is unique, then add it to a our cities list, otherwise move to the next combination
    if city not in cities:
        cities.append(city)

# Print the city count to confirm count out of the unique cities in the list.
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
# set up the url using imperial units to gather different weather info points
units = "imperial"

# set up the query using the above url and the api_key from the OpenWeatherMap site, then print that query url to confirm API access
query_url = f"{url}appid={api_key}&units&q="
print(query_url)

# create a list for each data point that will be called for each city
cityname = []
countryname = []
latitude = []
longitude = []
maxtemp = []
humidity = []
cloudiness = []
date = []
windspeed = []
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=59166562bfec44e3e627176a07991947&units&q=

# %%
# start a count in order for the entire list of cities to be searched
count = 1

print(f"Beginning Data Retrieval")
print(f"-----------------------------")

# partial query_url above, to get each data point for each city in the list, you must add the following code below
for city in cities:
# for each city in the overall list of cities gathered, find the following until the 500th city has been passed through and info has been gathered

    try:

        if (count > 500):
            break
#         start with a response to get the query_url for the city being focused on, then .json to gather all information.
#  then, the appends will add the relevant data points into each list that was created above
        response = requests.get(f"{query_url}{city}").json()
        cityname.append(response["name"])
        countryname.append(response["sys"]["country"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        maxtemp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        date.append(response["dt"])
        windspeed.append(response["wind"]["speed"])
#         once the data for the city in question is gathered, print the following statement to show the information has been gathered
        print(f"Processing data for City {count} ~ {city}")
        count += 1
        
        # wait for a second to avoid blocking the calls, gives buffer time between API calls
        time.sleep(1.00)
        
    except:
        print(f"{city} not found, moving on!")
#         this except function is used if the city in question does not have the data available in the OpenWeatherMap API
        
    continue
    
#     all information is gathered for each city that has data available
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing data for City 1 ~ cavalcante
# Processing data for City 2 ~ rikitea
# Processing data for City 3 ~ khatanga
# Processing data for City 4 ~ ilulissat
# Processing data for City 5 ~ cidreira
# Processing data for City 6 ~ pevek
# Processing data for City 7 ~ barrow
# Processing data for City 8 ~ vaini
# Processing data for City 9 ~ albany
# Processing data for City 10 ~ veraval
# Processing data for City 11 ~ kaitangata
# Processing data for City 12 ~ avera
# Processing data for City 13 ~ jamestown
# Processing data for City 14 ~ dikson
# Processing data for City 15 ~ ushuaia
# Processing data for City 16 ~ berlevag
# Processing data for City 17 ~ hobart
# Processing data for City 18 ~ north bend
# Processing data for City 19 ~ cururupu
# Processing data for City 20 ~ punta arenas
# Processing data for City 21 ~ nuuk
# Processing data for City 22 ~ flin flon
# Processing data for City 23 ~ buala
# Processing data for City 24 ~ cape town
# Processing data for City 25 ~ saint anthony
# Processing data for City 26 ~ seinajoki
# Processing data for City 27 ~ vostok
# Processing data for City 28 ~ airai
# Processing data for City 29 ~ comodoro rivadavia
# Processing data for City 30 ~ yellowknife
# Processing data for City 31 ~ talnakh
# Processing data for City 32 ~ bredasdorp
# Processing data for City 33 ~ bluff
# Processing data for City 34 ~ rio gallegos
# Processing data for City 35 ~ vilyuysk
# amderma not found, moving on!
# taolanaro not found, moving on!
# Processing data for City 36 ~ arraial do cabo
# Processing data for City 37 ~ new norfolk
# Processing data for City 38 ~ yangjiang
# Processing data for City 39 ~ yanam
# Processing data for City 40 ~ pundaguitan
# Processing data for City 41 ~ butaritari
# Processing data for City 42 ~ souillac
# Processing data for City 43 ~ bengkulu
# attawapiskat not found, moving on!
# Processing data for City 44 ~ saint george
# Processing data for City 45 ~ puerto ayora
# Processing data for City 46 ~ palampur
# illoqqortoormiut not found, moving on!
# Processing data for City 47 ~ assiniboia
# Processing data for City 48 ~ dandong
# Processing data for City 49 ~ grand gaube
# Processing data for City 50 ~ mataura
# Processing data for City 51 ~ noumea
# Processing data for City 52 ~ port alfred
# Processing data for City 53 ~ atuona
# Processing data for City 54 ~ sorland
# Processing data for City 55 ~ bambous virieux
# Processing data for City 56 ~ dwarka
# Processing data for City 57 ~ hulan
# Processing data for City 58 ~ barcelos
# Processing data for City 59 ~ avarua
# Processing data for City 60 ~ rocha
# Processing data for City 61 ~ pudozh
# saleaula not found, moving on!
# Processing data for City 62 ~ portland
# Processing data for City 63 ~ hilo
# Processing data for City 64 ~ novoalekseyevskaya
# Processing data for City 65 ~ broadford
# Processing data for City 66 ~ maniitsoq
# Processing data for City 67 ~ castro
# Processing data for City 68 ~ arlit
# Processing data for City 69 ~ faanui
# Processing data for City 70 ~ fagersta
# Processing data for City 71 ~ quatre cocos
# Processing data for City 72 ~ busselton
# Processing data for City 73 ~ ardu
# Processing data for City 74 ~ vila velha
# Processing data for City 75 ~ yangambi
# Processing data for City 76 ~ cayenne
# Processing data for City 77 ~ natal
# Processing data for City 78 ~ kismayo
# skalistyy not found, moving on!
# Processing data for City 79 ~ port-gentil
# Processing data for City 80 ~ hithadhoo
# Processing data for City 81 ~ borba
# ngukurr not found, moving on!
# Processing data for City 82 ~ narsaq
# Processing data for City 83 ~ lebu
# Processing data for City 84 ~ saint-leu
# lolua not found, moving on!
# Processing data for City 85 ~ qaqortoq
# Processing data for City 86 ~ east london
# Processing data for City 87 ~ alofi
# Processing data for City 88 ~ dingle
# Processing data for City 89 ~ jangipur
# Processing data for City 90 ~ tiksi
# Processing data for City 91 ~ georgetown
# Processing data for City 92 ~ yarmouth
# Processing data for City 93 ~ kapaa
# Processing data for City 94 ~ nome
# safwah not found, moving on!
# Processing data for City 95 ~ guerrero negro
# Processing data for City 96 ~ anloga
# Processing data for City 97 ~ camacha
# Processing data for City 98 ~ tasiilaq
# Processing data for City 99 ~ prince rupert
# Processing data for City 100 ~ mahebourg
# Processing data for City 101 ~ carnarvon
# Processing data for City 102 ~ komsomolskiy
# Processing data for City 103 ~ petropavlovsk-kamchatskiy
# Processing data for City 104 ~ upernavik
# Processing data for City 105 ~ luderitz
# Processing data for City 106 ~ aklavik
# Processing data for City 107 ~ goderich
# Processing data for City 108 ~ lavrentiya
# palabuhanratu not found, moving on!
# Processing data for City 109 ~ stokmarknes
# tumannyy not found, moving on!
# Processing data for City 110 ~ esperance
# Processing data for City 111 ~ iqaluit
# Processing data for City 112 ~ hermanus
# Processing data for City 113 ~ sitka
# Processing data for City 114 ~ pangnirtung
# Processing data for City 115 ~ tuktoyaktuk
# Processing data for City 116 ~ zamora
# Processing data for City 117 ~ nikolskoye
# Processing data for City 118 ~ biak
# Processing data for City 119 ~ huarmey
# mys shmidta not found, moving on!
# Processing data for City 120 ~ morros
# Processing data for City 121 ~ garowe
# Processing data for City 122 ~ kodiak
# belushya guba not found, moving on!
# Processing data for City 123 ~ reyes
# Processing data for City 124 ~ izumo
# Processing data for City 125 ~ bethel
# samusu not found, moving on!
# Processing data for City 126 ~ altay
# Processing data for City 127 ~ ponta do sol
# Processing data for City 128 ~ norman wells
# Processing data for City 129 ~ dunedin
# Processing data for City 130 ~ kupino
# louisbourg not found, moving on!
# Processing data for City 131 ~ klaksvik
# Processing data for City 132 ~ qaanaaq
# Processing data for City 133 ~ caorle
# tsihombe not found, moving on!
# Processing data for City 134 ~ pedregulho
# Processing data for City 135 ~ kiama
# Processing data for City 136 ~ bonthe
# grand river south east not found, moving on!
# Processing data for City 137 ~ celestun
# barentsburg not found, moving on!
# Processing data for City 138 ~ flinders
# Processing data for City 139 ~ caravelas
# Processing data for City 140 ~ villazon
# sentyabrskiy not found, moving on!
# Processing data for City 141 ~ hofn
# Processing data for City 142 ~ saskylakh
# Processing data for City 143 ~ port hardy
# Processing data for City 144 ~ katsuura
# Processing data for City 145 ~ kaeo
# Processing data for City 146 ~ chokurdakh
# Processing data for City 147 ~ victoria
# Processing data for City 148 ~ kavieng
# Processing data for City 149 ~ jingdezhen
# Processing data for City 150 ~ huilong
# duz not found, moving on!
# Processing data for City 151 ~ the valley
# vaitupu not found, moving on!
# Processing data for City 152 ~ asau
# Processing data for City 153 ~ fortuna
# Processing data for City 154 ~ vila franca do campo
# Processing data for City 155 ~ ribeira grande
# Processing data for City 156 ~ benguela
# Processing data for City 157 ~ rabo de peixe
# nizhneyansk not found, moving on!
# Processing data for City 158 ~ san patricio
# Processing data for City 159 ~ saint-francois
# Processing data for City 160 ~ pitsunda
# Processing data for City 161 ~ burley
# Processing data for City 162 ~ rawson
# Processing data for City 163 ~ bangassou
# Processing data for City 164 ~ isangel
# Processing data for City 165 ~ mar del plata
# Processing data for City 166 ~ raymond terrace
# Processing data for City 167 ~ kaniama
# Processing data for City 168 ~ port elizabeth
# Processing data for City 169 ~ simav
# Processing data for City 170 ~ minbu
# Processing data for City 171 ~ vao
# Processing data for City 172 ~ cabo san lucas
# Processing data for City 173 ~ reo
# Processing data for City 174 ~ thompson
# wulanhaote not found, moving on!
# Processing data for City 175 ~ galveston
# felidhoo not found, moving on!
# Processing data for City 176 ~ aljezur
# Processing data for City 177 ~ prienai
# Processing data for City 178 ~ vardo
# Processing data for City 179 ~ makaha
# Processing data for City 180 ~ chuy
# Processing data for City 181 ~ awbari
# Processing data for City 182 ~ paoua
# Processing data for City 183 ~ tchollire
# Processing data for City 184 ~ buchanan
# Processing data for City 185 ~ longyearbyen
# Processing data for City 186 ~ sinnamary
# Processing data for City 187 ~ troitsko-pechorsk
# Processing data for City 188 ~ hambantota
# Processing data for City 189 ~ mumbwa
# toftir not found, moving on!
# Processing data for City 190 ~ aldan
# Processing data for City 191 ~ kenora
# Processing data for City 192 ~ tessalit
# Processing data for City 193 ~ sao felix do xingu
# Processing data for City 194 ~ cap malheureux
# Processing data for City 195 ~ mount isa
# Processing data for City 196 ~ ulaanbaatar
# Processing data for City 197 ~ saint-philippe
# Processing data for City 198 ~ jinka
# Processing data for City 199 ~ port lincoln
# Processing data for City 200 ~ kupang
# Processing data for City 201 ~ tuatapere
# Processing data for City 202 ~ inhambane
# Processing data for City 203 ~ codrington
# Processing data for City 204 ~ kalga
# Processing data for City 205 ~ okha
# Processing data for City 206 ~ trinidad
# Processing data for City 207 ~ port augusta
# Processing data for City 208 ~ auki
# Processing data for City 209 ~ kaputa
# Processing data for City 210 ~ luwuk
# Processing data for City 211 ~ dinguiraye
# Processing data for City 212 ~ champerico
# Processing data for City 213 ~ baruun-urt
# Processing data for City 214 ~ salalah
# Processing data for City 215 ~ acapulco
# Processing data for City 216 ~ tadine
# marcona not found, moving on!
# Processing data for City 217 ~ jackson
# Processing data for City 218 ~ ilam
# addi ugri not found, moving on!
# Processing data for City 219 ~ ketchikan
# Processing data for City 220 ~ boyolangu
# Processing data for City 221 ~ cody
# Processing data for City 222 ~ college
# Processing data for City 223 ~ vestmannaeyjar
# Processing data for City 224 ~ hami
# Processing data for City 225 ~ khorixas
# Processing data for City 226 ~ bathsheba
# Processing data for City 227 ~ kishi
# Processing data for City 228 ~ xiaoweizhai
# Processing data for City 229 ~ kruisfontein
# Processing data for City 230 ~ boueni
# Processing data for City 231 ~ cherskiy
# Processing data for City 232 ~ taksimo
# astipalaia not found, moving on!
# Processing data for City 233 ~ sioux lookout
# Processing data for City 234 ~ wahpeton
# Processing data for City 235 ~ saldanha
# Processing data for City 236 ~ nantucket
# Processing data for City 237 ~ lugovoy
# Processing data for City 238 ~ charters towers
# Processing data for City 239 ~ verkhnyaya inta
# Processing data for City 240 ~ provideniya
# Processing data for City 241 ~ riyadh
# Processing data for City 242 ~ pak phanang
# Processing data for City 243 ~ balad
# bursol not found, moving on!
# kerteh not found, moving on!
# Processing data for City 244 ~ mizan teferi
# Processing data for City 245 ~ albanel
# Processing data for City 246 ~ fort abbas
# Processing data for City 247 ~ zaoyang
# aflu not found, moving on!
# Processing data for City 248 ~ plaridel
# Processing data for City 249 ~ miraflores
# juifang not found, moving on!
# Processing data for City 250 ~ mayumba
# Processing data for City 251 ~ sao filipe
# Processing data for City 252 ~ chateau-gontier
# Processing data for City 253 ~ council bluffs
# Processing data for City 254 ~ paciran
# Processing data for City 255 ~ oktyabrskiy
# Processing data for City 256 ~ sambava
# Processing data for City 257 ~ pitlochry
# Processing data for City 258 ~ bridlington
# Processing data for City 259 ~ saint-augustin
# Processing data for City 260 ~ viedma
# Processing data for City 261 ~ sakakah
# Processing data for City 262 ~ macheng
# Processing data for City 263 ~ atikokan
# Processing data for City 264 ~ geraldton
# Processing data for City 265 ~ kudahuvadhoo
# Processing data for City 266 ~ neuquen
# Processing data for City 267 ~ haines junction
# Processing data for City 268 ~ lata
# Processing data for City 269 ~ oyem
# Processing data for City 270 ~ jalu
# Processing data for City 271 ~ brest
# ruatoria not found, moving on!
# Processing data for City 272 ~ yurimaguas
# Processing data for City 273 ~ agadez
# Processing data for City 274 ~ beloha
# Processing data for City 275 ~ mandali
# Processing data for City 276 ~ leningradskiy
# Processing data for City 277 ~ trairi
# Processing data for City 278 ~ hervey bay
# Processing data for City 279 ~ sola
# Processing data for City 280 ~ ostrovnoy
# Processing data for City 281 ~ sterling
# Processing data for City 282 ~ djambala
# Processing data for City 283 ~ tual
# Processing data for City 284 ~ padang
# Processing data for City 285 ~ kahului
# kargapolye not found, moving on!
# Processing data for City 286 ~ eresos
# Processing data for City 287 ~ sol-iletsk
# Processing data for City 288 ~ isabela
# Processing data for City 289 ~ sinnai
# Processing data for City 290 ~ san pedro
# Processing data for City 291 ~ poum
# Processing data for City 292 ~ salinopolis
# Processing data for City 293 ~ saint-pierre
# Processing data for City 294 ~ ipixuna
# Processing data for City 295 ~ tilichiki
# Processing data for City 296 ~ two hills
# Processing data for City 297 ~ constitucion
# Processing data for City 298 ~ bemidji
# Processing data for City 299 ~ tarauaca
# Processing data for City 300 ~ tungor
# Processing data for City 301 ~ nalut
# Processing data for City 302 ~ itaquyry
# Processing data for City 303 ~ manadhoo
# Processing data for City 304 ~ gubkinskiy
# Processing data for City 305 ~ opuwo
# Processing data for City 306 ~ pangkalanbuun
# Processing data for City 307 ~ lavello
# Processing data for City 308 ~ ulaangom
# Processing data for City 309 ~ muisne
# Processing data for City 310 ~ porto novo
# Processing data for City 311 ~ jasper
# Processing data for City 312 ~ majene
# Processing data for City 313 ~ ornskoldsvik
# Processing data for City 314 ~ laguna
# Processing data for City 315 ~ ust-ishim
# Processing data for City 316 ~ san antonio
# Processing data for City 317 ~ chapais
# Processing data for City 318 ~ banjar
# Processing data for City 319 ~ san martin
# Processing data for City 320 ~ saint-joseph
# Processing data for City 321 ~ basmat
# Processing data for City 322 ~ kihurio
# Processing data for City 323 ~ ulfborg
# Processing data for City 324 ~ orlik
# Processing data for City 325 ~ torbay
# Processing data for City 326 ~ touros
# Processing data for City 327 ~ kurchum
# Processing data for City 328 ~ phetchabun
# Processing data for City 329 ~ turbat
# Processing data for City 330 ~ sechura
# Processing data for City 331 ~ malvern
# Processing data for City 332 ~ barma
# Processing data for City 333 ~ ust-tsilma
# Processing data for City 334 ~ coolum beach
# Processing data for City 335 ~ ahipara
# Processing data for City 336 ~ hirara
# Processing data for City 337 ~ sukhumi
# Processing data for City 338 ~ chimbote
# Processing data for City 339 ~ vangaindrano
# Processing data for City 340 ~ inuvik
# Processing data for City 341 ~ soyo
# Processing data for City 342 ~ imbituba
# Processing data for City 343 ~ tenamaxtlan
# Processing data for City 344 ~ grand-santi
# Processing data for City 345 ~ obama
# Processing data for City 346 ~ teguldet
# Processing data for City 347 ~ sidhi
# Processing data for City 348 ~ ugoofaaru
# balykshi not found, moving on!
# Processing data for City 349 ~ languyan
# Processing data for City 350 ~ kitimat
# Processing data for City 351 ~ kalakamati
# Processing data for City 352 ~ baykit
# meyungs not found, moving on!
# Processing data for City 353 ~ puerto escondido
# Processing data for City 354 ~ folldal
# Processing data for City 355 ~ amahai
# Processing data for City 356 ~ mae sot
# Processing data for City 357 ~ pacific grove
# Processing data for City 358 ~ mairana
# Processing data for City 359 ~ kayes
# Processing data for City 360 ~ abu dhabi
# Processing data for City 361 ~ stetseva
# Processing data for City 362 ~ yar-sale
# Processing data for City 363 ~ mizdah
# Processing data for City 364 ~ chardara
# Processing data for City 365 ~ fort stewart
# Processing data for City 366 ~ shingu
# Processing data for City 367 ~ muzhi
# Processing data for City 368 ~ ambilobe
# Processing data for City 369 ~ jacareacanga
# Processing data for City 370 ~ narva-joesuu
# Processing data for City 371 ~ omagari
# Processing data for City 372 ~ sorong
# Processing data for City 373 ~ urumqi
# Processing data for City 374 ~ bontang
# Processing data for City 375 ~ makubetsu
# Processing data for City 376 ~ palmer
# kamenskoye not found, moving on!
# mahaicony not found, moving on!
# Processing data for City 377 ~ eureka
# Processing data for City 378 ~ yerbogachen
# Processing data for City 379 ~ beaufort
# Processing data for City 380 ~ henties bay
# Processing data for City 381 ~ magadan
# barawe not found, moving on!
# Processing data for City 382 ~ sovetskiy
# Processing data for City 383 ~ cochrane
# Processing data for City 384 ~ surt
# kuche not found, moving on!
# Processing data for City 385 ~ mvuma
# Processing data for City 386 ~ carutapera
# Processing data for City 387 ~ rudbar
# Processing data for City 388 ~ buraydah
# Processing data for City 389 ~ poronaysk
# Processing data for City 390 ~ alappuzha
# Processing data for City 391 ~ herat
# Processing data for City 392 ~ praia da vitoria
# Processing data for City 393 ~ tynda
# Processing data for City 394 ~ mount gambier
# Processing data for City 395 ~ leh
# Processing data for City 396 ~ puerto ayacucho
# Processing data for City 397 ~ abu samrah
# Processing data for City 398 ~ powell river
# Processing data for City 399 ~ naryan-mar
# Processing data for City 400 ~ shu
# Processing data for City 401 ~ tezu
# Processing data for City 402 ~ tucupita
# Processing data for City 403 ~ iskateley
# Processing data for City 404 ~ bay roberts
# Processing data for City 405 ~ vila
# tanshui not found, moving on!
# Processing data for City 406 ~ hasaki
# Processing data for City 407 ~ alice springs
# Processing data for City 408 ~ mangit
# Processing data for City 409 ~ awjilah
# Processing data for City 410 ~ yuli
# Processing data for City 411 ~ batagay
# Processing data for City 412 ~ putina
# karaul not found, moving on!
# Processing data for City 413 ~ lakeway
# bossembele not found, moving on!
# Processing data for City 414 ~ ngunguru
# Processing data for City 415 ~ zhezkazgan
# Processing data for City 416 ~ trelew
# Processing data for City 417 ~ miajadas
# Processing data for City 418 ~ upala
# Processing data for City 419 ~ cabedelo
# Processing data for City 420 ~ pisco
# Processing data for City 421 ~ te anau
# Processing data for City 422 ~ sulangan
# Processing data for City 423 ~ dombarovskiy
# Processing data for City 424 ~ richards bay
# Processing data for City 425 ~ bakchar
# Processing data for City 426 ~ waddan
# Processing data for City 427 ~ fairbanks
# Processing data for City 428 ~ egvekinot
# Processing data for City 429 ~ ukiah
# Processing data for City 430 ~ salgueiro
# Processing data for City 431 ~ loandjili
# Processing data for City 432 ~ cabras
# Processing data for City 433 ~ akranes
# Processing data for City 434 ~ tura
# Processing data for City 435 ~ maibong
# Processing data for City 436 ~ luoyang
# Processing data for City 437 ~ bilibino
# Processing data for City 438 ~ burns lake
# Processing data for City 439 ~ dalby
# Processing data for City 440 ~ kailua
# Processing data for City 441 ~ gat
# Processing data for City 442 ~ rialma
# Processing data for City 443 ~ kathu
# Processing data for City 444 ~ kidal
# Processing data for City 445 ~ vanavara
# Processing data for City 446 ~ lompoc
# Processing data for City 447 ~ progreso
# Processing data for City 448 ~ manokwari
# Processing data for City 449 ~ tomohon
# Processing data for City 450 ~ anadyr
# Processing data for City 451 ~ montrose
# Processing data for City 452 ~ paka
# Processing data for City 453 ~ shillong
# Processing data for City 454 ~ lasem
# Processing data for City 455 ~ klyuchi
# Processing data for City 456 ~ beringovskiy
# Processing data for City 457 ~ bloomfield
# barbar not found, moving on!
# Processing data for City 458 ~ omboue
# Processing data for City 459 ~ norsup
# Processing data for City 460 ~ guarapari
# Processing data for City 461 ~ kununurra
# Processing data for City 462 ~ fare
# Processing data for City 463 ~ malakal
# Processing data for City 464 ~ westport
# Processing data for City 465 ~ killybegs
# Processing data for City 466 ~ masterton
# Processing data for City 467 ~ dawei
# Processing data for City 468 ~ deputatskiy
# Processing data for City 469 ~ honiara
# Processing data for City 470 ~ elbistan
# Processing data for City 471 ~ chicama
# Processing data for City 472 ~ kloulklubed
# Processing data for City 473 ~ lianran
# thilogne not found, moving on!
# bolshoye sorokino not found, moving on!
# Processing data for City 474 ~ thinadhoo
# Processing data for City 475 ~ san quintin
# Processing data for City 476 ~ la rioja
# Processing data for City 477 ~ tabuk
# Processing data for City 478 ~ kachug
# Processing data for City 479 ~ mocuba
# Processing data for City 480 ~ maxixe
# Processing data for City 481 ~ necochea
# Processing data for City 482 ~ springdale
# Processing data for City 483 ~ koumac
# Processing data for City 484 ~ coihaique
# Processing data for City 485 ~ lazaro cardenas
# Processing data for City 486 ~ severo-yeniseyskiy
# Processing data for City 487 ~ yeppoon
# Processing data for City 488 ~ dalaba
# Processing data for City 489 ~ namibe
# Processing data for City 490 ~ georgiyevka
# xiongshi not found, moving on!
# Processing data for City 491 ~ emba
# Processing data for City 492 ~ meulaboh
# Processing data for City 493 ~ peniche
# Processing data for City 494 ~ clinton
# Processing data for City 495 ~ nampa
# Processing data for City 496 ~ port keats
# nguiu not found, moving on!
# Processing data for City 497 ~ port macquarie
# Processing data for City 498 ~ khani
# Processing data for City 499 ~ bara
# Processing data for City 500 ~ san angelo

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dataframe in which to place all API data that was gathered. 
# list is used to gather each dataset that was grabbed from API. put each list together with titles for the dataframe
weather = {
    "City": cityname,
    "Cloudiness": cloudiness, 
    "Country": countryname,
    "Date": date, 
    "Humidity": humidity,
    "Latitude": latitude, 
    "Longitude": longitude, 
    "Max Temp": maxtemp,
    "Wind Speed":windspeed
}

# create a dataframe from the lists of info, will be the columns
# show the count of cities, should be 500 total
weather_df = pd.DataFrame(weather)
weather_df.count()
# Out:
# City          500
# Cloudiness    500
# Country       500
# Date          500
# Humidity      500
# Latitude      500
# Longitude     500
# Max Temp      500
# Wind Speed    500
# dtype: int64

# %%
weather_df.to_csv(output_data_file)
# export the dataframe with all cities to a csv
weather_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0  Cavalcante           0      BR  1591749708        60    -13.80     -47.46
# 1     Rikitea           1      PF  1591749709        81    -23.12    -134.97
# 2    Khatanga          23      RU  1591749711        39     71.97     102.50
# 3   Ilulissat         100      GL  1591749712        74     69.22     -51.10
# 4    Cidreira         100      BR  1591749598        86    -30.18     -50.21
#
#    Max Temp  Wind Speed
# 0    293.30        1.86
# 1    297.74        4.98
# 2    285.11        5.86
# 3    276.15        1.50
# 4    289.19        1.15

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
area = (30 * np.random.rand(len(weather_df)))**2
colors = np.random.rand(len(weather_df))
# randomize the colors for each city when displayed in a plot

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(10, 8))
plt.scatter(weather_df["Latitude"], weather_df["Max Temp"], marker="o", s=area, c=colors, alpha=0.5)
# choose the proper columns from the dataframe when creating the plot
plt.title(f"Latitude Vs Temperature ({time.strftime('%x')})")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.tight_layout()
plt.savefig("LatitudeVsTemperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10, 8))
plt.scatter(weather_df["Latitude"], weather_df["Humidity"], marker="o", s=area, c=colors, alpha=0.5)
plt.title(f"Latitude Vs Humidity ({time.strftime('%x')})")
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.ylim(0, 100)
plt.grid(True)


plt.tight_layout()
plt.savefig("LatitudeVsHumidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10, 8))
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness"], marker="o", s=area, c=colors, alpha=0.5)
plt.title(f"Latitude Vs Cloudiness ({time.strftime('%x')})")
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.tight_layout()
plt.savefig("LatitudeVsCloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10, 8))
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed"], marker="o", s=area, c=colors, alpha=0.5)
plt.title(f"Latitude Vs Wind Speed ({time.strftime('%x')})")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.tight_layout()
plt.savefig("LatitudeVsWindSpeed.png")
plt.show()

# %% [markdown]
# ## Secondary City List and Analysis

# %% [markdown]
# ### Create a new list of cities from random latitude and longitude combinations

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations, we will get 1500 combinations of lat/lng coordinates.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
# numpy uses random to get a list of numbers for each list, 1500 for lat, 1500 for lng.
# lat_lngs is zipped together to make one list out of two
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
# for each combination in the list of lat_lng, use citipy to find the nearest city to the lat/lng location
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
#     citypy module is used to call out the city name for the list of lat/lng combinations

    # If the city is unique, then add it to a our cities list, otherwise move to the next combination
    if city not in cities:
        cities.append(city)

# Print the city count to confirm count out of the unique cities in the list.
len(cities)
# Out:
# 606

# %% [markdown]
# ## API Call

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
# set up the url using imperial units to gather different weather info points
units = "imperial"

# set up the query using the above url and the api_key from the OpenWeatherMap site, then print that query url to confirm API access
query_url = f"{url}appid={api_key}&units&q="
print(query_url)

# create a list for each data point that will be called for each city
cityname = []
countryname = []
latitude = []
longitude = []
maxtemp = []
humidity = []
cloudiness = []
date = []
windspeed = []
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=59166562bfec44e3e627176a07991947&units&q=

# %%
# start a count in order for the entire list of cities to be searched
count = 1

print(f"Beginning Data Retrieval")
print(f"-----------------------------")

# partial query_url above, to get each data point for each city in the list, you must add the following code below
for city in cities:
# for each city in the overall list of cities gathered, find the following until the 500th city has been passed through and info has been gathered

    try:

        if (count > 500):
            break
#         start with a response to get the query_url for the city being focused on, then .json to gather all information.
#  then, the appends will add the relevant data points into each list that was created above
        response = requests.get(f"{query_url}{city}").json()
        cityname.append(response["name"])
        countryname.append(response["sys"]["country"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        maxtemp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        date.append(response["dt"])
        windspeed.append(response["wind"]["speed"])
#         once the data for the city in question is gathered, print the following statement to show the information has been gathered
        print(f"Processing data for City {count} ~ {city}")
        count += 1
        
        # wait for a second to avoid blocking the calls, gives buffer time between API calls
        time.sleep(1.00)
        
    except:
        print(f"{city} not found, moving on!")
#         this except function is used if the city in question does not have the data available in the OpenWeatherMap API
        
    continue
    
#     all information is gathered for each city that has data available
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing data for City 1 ~ fergus falls
# Processing data for City 2 ~ marsa matruh
# Processing data for City 3 ~ pangnirtung
# Processing data for City 4 ~ tamiahua
# Processing data for City 5 ~ hermanus
# Processing data for City 6 ~ port alfred
# Processing data for City 7 ~ hami
# Processing data for City 8 ~ lorengau
# Processing data for City 9 ~ talnakh
# Processing data for City 10 ~ tortoli
# Processing data for City 11 ~ cape town
# grand river south east not found, moving on!
# Processing data for City 12 ~ makakilo city
# samusu not found, moving on!
# Processing data for City 13 ~ saint george
# Processing data for City 14 ~ alofi
# Processing data for City 15 ~ ushuaia
# Processing data for City 16 ~ puerto ayora
# Processing data for City 17 ~ rikitea
# Processing data for City 18 ~ ust-kuyga
# Processing data for City 19 ~ valdosta
# Processing data for City 20 ~ harper
# Processing data for City 21 ~ kapaa
# Processing data for City 22 ~ khatanga
# Processing data for City 23 ~ severo-kurilsk
# Processing data for City 24 ~ mataura
# Processing data for City 25 ~ yellowknife
# Processing data for City 26 ~ hobart
# Processing data for City 27 ~ manggar
# Processing data for City 28 ~ clyde river
# Processing data for City 29 ~ fort morgan
# Processing data for City 30 ~ grindavik
# Processing data for City 31 ~ novyy urengoy
# Processing data for City 32 ~ mahebourg
# Processing data for City 33 ~ busselton
# Processing data for City 34 ~ junin
# Processing data for City 35 ~ narsaq
# Processing data for City 36 ~ sucua
# Processing data for City 37 ~ codrington
# Processing data for City 38 ~ poum
# Processing data for City 39 ~ tiksi
# marcona not found, moving on!
# Processing data for City 40 ~ bredasdorp
# Processing data for City 41 ~ new norfolk
# Processing data for City 42 ~ san ramon
# Processing data for City 43 ~ qaanaaq
# Processing data for City 44 ~ kaitangata
# Processing data for City 45 ~ hasaki
# Processing data for City 46 ~ ndele
# Processing data for City 47 ~ avarua
# Processing data for City 48 ~ port elizabeth
# Processing data for City 49 ~ thaba-tseka
# Processing data for City 50 ~ bambous virieux
# Processing data for City 51 ~ castro
# Processing data for City 52 ~ viedma
# Processing data for City 53 ~ thompson
# Processing data for City 54 ~ pio ix
# Processing data for City 55 ~ tabory
# Processing data for City 56 ~ pachino
# Processing data for City 57 ~ ozinki
# Processing data for City 58 ~ perove
# Processing data for City 59 ~ christchurch
# saleaula not found, moving on!
# Processing data for City 60 ~ inirida
# Processing data for City 61 ~ atuona
# Processing data for City 62 ~ seoul
# Processing data for City 63 ~ dunedin
# Processing data for City 64 ~ whitehorse
# Processing data for City 65 ~ tuktoyaktuk
# Processing data for City 66 ~ bluff
# Processing data for City 67 ~ vaini
# Processing data for City 68 ~ zaysan
# Processing data for City 69 ~ chipinge
# Processing data for City 70 ~ saskylakh
# Processing data for City 71 ~ matara
# Processing data for City 72 ~ port blair
# Processing data for City 73 ~ hilo
# Processing data for City 74 ~ kodiak
# Processing data for City 75 ~ cherskiy
# belushya guba not found, moving on!
# illoqqortoormiut not found, moving on!
# barentsburg not found, moving on!
# Processing data for City 76 ~ saint-philippe
# Processing data for City 77 ~ svobodnyy
# Processing data for City 78 ~ punta arenas
# Processing data for City 79 ~ bethel
# Processing data for City 80 ~ iqaluit
# Processing data for City 81 ~ vostok
# Processing data for City 82 ~ albert lea
# Processing data for City 83 ~ ixtapa
# Processing data for City 84 ~ divo
# Processing data for City 85 ~ chuy
# taolanaro not found, moving on!
# Processing data for City 86 ~ mustvee
# Processing data for City 87 ~ oum hadjer
# Processing data for City 88 ~ batticaloa
# Processing data for City 89 ~ hofn
# tsihombe not found, moving on!
# Processing data for City 90 ~ rawson
# Processing data for City 91 ~ townsville
# Processing data for City 92 ~ jamestown
# Processing data for City 93 ~ albany
# Processing data for City 94 ~ shcherbynivka
# Processing data for City 95 ~ portalegre
# Processing data for City 96 ~ mount gambier
# Processing data for City 97 ~ simao dias
# Processing data for City 98 ~ upernavik
# Processing data for City 99 ~ otavi
# Processing data for City 100 ~ krasnoarmeysk
# Processing data for City 101 ~ kayankulam
# Processing data for City 102 ~ ilulissat
# gulshat not found, moving on!
# Processing data for City 103 ~ manacapuru
# Processing data for City 104 ~ biltine
# nizhneyansk not found, moving on!
# Processing data for City 105 ~ calama
# Processing data for City 106 ~ nome
# Processing data for City 107 ~ zlobin
# Processing data for City 108 ~ hithadhoo
# Processing data for City 109 ~ fortuna
# Processing data for City 110 ~ ivdel
# Processing data for City 111 ~ tekirdag
# Processing data for City 112 ~ hailar
# Processing data for City 113 ~ ahuimanu
# Processing data for City 114 ~ lata
# tumannyy not found, moving on!
# attawapiskat not found, moving on!
# Processing data for City 115 ~ san patricio
# umzimvubu not found, moving on!
# Processing data for City 116 ~ madera
# Processing data for City 117 ~ namatanai
# Processing data for City 118 ~ dingle
# mys shmidta not found, moving on!
# Processing data for City 119 ~ barrow
# Processing data for City 120 ~ caravelas
# Processing data for City 121 ~ shingu
# Processing data for City 122 ~ sumenep
# Processing data for City 123 ~ murindo
# Processing data for City 124 ~ ostersund
# Processing data for City 125 ~ rio gallegos
# Processing data for City 126 ~ bubaque
# Processing data for City 127 ~ saint-augustin
# Processing data for City 128 ~ valentin gomez farias
# Processing data for City 129 ~ kununurra
# Processing data for City 130 ~ butaritari
# Processing data for City 131 ~ akyab
# palabuhanratu not found, moving on!
# Processing data for City 132 ~ norman wells
# Processing data for City 133 ~ mar del plata
# Processing data for City 134 ~ trairi
# Processing data for City 135 ~ vila franca do campo
# Processing data for City 136 ~ sao miguel do araguaia
# Processing data for City 137 ~ provideniya
# Processing data for City 138 ~ georgetown
# Processing data for City 139 ~ cabo san lucas
# umm durman not found, moving on!
# Processing data for City 140 ~ geraldton
# Processing data for City 141 ~ guerrero negro
# Processing data for City 142 ~ arraial do cabo
# Processing data for City 143 ~ metro
# Processing data for City 144 ~ taree
# Processing data for City 145 ~ cairns
# Processing data for City 146 ~ salur
# Processing data for City 147 ~ antofagasta
# Processing data for City 148 ~ east london
# Processing data for City 149 ~ anadyr
# Processing data for City 150 ~ saint anthony
# Processing data for City 151 ~ bilibino
# Processing data for City 152 ~ amberg
# Processing data for City 153 ~ flin flon
# Processing data for City 154 ~ lompoc
# Processing data for City 155 ~ ponta do sol
# Processing data for City 156 ~ port hardy
# Processing data for City 157 ~ carnarvon
# Processing data for City 158 ~ kloulklubed
# Processing data for City 159 ~ vallam
# Processing data for City 160 ~ igrim
# Processing data for City 161 ~ isangel
# Processing data for City 162 ~ aykhal
# Processing data for City 163 ~ bud
# Processing data for City 164 ~ kavieng
# Processing data for City 165 ~ pacific grove
# jiddah not found, moving on!
# ambodifototra not found, moving on!
# Processing data for City 166 ~ yizhivtsi
# sentyabrskiy not found, moving on!
# Processing data for City 167 ~ high level
# Processing data for City 168 ~ oranjemund
# Processing data for City 169 ~ uniara
# Processing data for City 170 ~ chimbote
# Processing data for City 171 ~ asau
# Processing data for City 172 ~ werda
# Processing data for City 173 ~ comodoro rivadavia
# Processing data for City 174 ~ lagoa
# Processing data for City 175 ~ maceio
# Processing data for City 176 ~ bonthe
# Processing data for City 177 ~ hambantota
# Processing data for City 178 ~ batagay-alyta
# Processing data for City 179 ~ bathsheba
# Processing data for City 180 ~ kalmunai
# Processing data for City 181 ~ bardiyah
# Processing data for City 182 ~ jaboticabal
# Processing data for City 183 ~ ribeira grande
# Processing data for City 184 ~ mayo
# Processing data for City 185 ~ cidreira
# Processing data for City 186 ~ bluefield
# Processing data for City 187 ~ beira
# Processing data for City 188 ~ dikson
# Processing data for City 189 ~ gilgit
# Processing data for City 190 ~ nanortalik
# Processing data for City 191 ~ adrar
# Processing data for City 192 ~ zabid
# Processing data for City 193 ~ perth
# Processing data for City 194 ~ cap malheureux
# Processing data for City 195 ~ cedar city
# Processing data for City 196 ~ padang
# Processing data for City 197 ~ pasighat
# Processing data for City 198 ~ manoel urbano
# Processing data for City 199 ~ kano
# Processing data for City 200 ~ komsomolskiy
# Processing data for City 201 ~ lavagna
# Processing data for City 202 ~ port lincoln
# Processing data for City 203 ~ sao joao da barra
# Processing data for City 204 ~ okhotsk
# Processing data for City 205 ~ sinnamary
# Processing data for City 206 ~ vilya
# Processing data for City 207 ~ gashua
# Processing data for City 208 ~ puerto carreno
# Processing data for City 209 ~ along
# Processing data for City 210 ~ zhigansk
# Processing data for City 211 ~ stettler
# Processing data for City 212 ~ portland
# Processing data for City 213 ~ muyinga
# amderma not found, moving on!
# Processing data for City 214 ~ hovd
# Processing data for City 215 ~ lake havasu city
# toliary not found, moving on!
# Processing data for City 216 ~ saldanha
# Processing data for City 217 ~ nikolskoye
# Processing data for City 218 ~ rock springs
# Processing data for City 219 ~ mocajuba
# Processing data for City 220 ~ san cristobal
# Processing data for City 221 ~ pecos
# Processing data for City 222 ~ agadez
# Processing data for City 223 ~ xiaoweizhai
# Processing data for City 224 ~ powell river
# Processing data for City 225 ~ hope
# Processing data for City 226 ~ takoradi
# Processing data for City 227 ~ mahibadhoo
# Processing data for City 228 ~ lebu
# Processing data for City 229 ~ paka
# Processing data for City 230 ~ ereymentau
# Processing data for City 231 ~ camacha
# Processing data for City 232 ~ russkaya polyana
# Processing data for City 233 ~ mount isa
# Processing data for City 234 ~ hualmay
# Processing data for City 235 ~ saint-joseph
# Processing data for City 236 ~ aketi
# Processing data for City 237 ~ la ronge
# Processing data for City 238 ~ klaksvik
# Processing data for City 239 ~ abu samrah
# Processing data for City 240 ~ lima
# Processing data for City 241 ~ victoria
# Processing data for City 242 ~ luderitz
# Processing data for City 243 ~ chokurdakh
# Processing data for City 244 ~ taoudenni
# Processing data for City 245 ~ cayenne
# Processing data for City 246 ~ yar-sale
# Processing data for City 247 ~ labuhan
# Processing data for City 248 ~ tahe
# Processing data for City 249 ~ cozumel
# dzhusaly not found, moving on!
# Processing data for City 250 ~ gotsu
# Processing data for City 251 ~ haines junction
# Processing data for City 252 ~ krasnoselkup
# Processing data for City 253 ~ ust-maya
# Processing data for City 254 ~ bowen
# Processing data for City 255 ~ rajkot
# Processing data for City 256 ~ iskandar
# Processing data for City 257 ~ salcia
# Processing data for City 258 ~ damghan
# Processing data for City 259 ~ sioux lookout
# Processing data for City 260 ~ sitka
# Processing data for City 261 ~ nara
# Processing data for City 262 ~ jalu
# Processing data for City 263 ~ qeshm
# Processing data for City 264 ~ cercal
# Processing data for City 265 ~ olga
# Processing data for City 266 ~ lokosovo
# bolungarvik not found, moving on!
# Processing data for City 267 ~ chissamba
# Processing data for City 268 ~ varhaug
# Processing data for City 269 ~ sydney
# Processing data for City 270 ~ longyearbyen
# Processing data for City 271 ~ abrau-dyurso
# Processing data for City 272 ~ rio claro
# Processing data for City 273 ~ torbay
# Processing data for City 274 ~ trofors
# Processing data for City 275 ~ alta floresta
# Processing data for City 276 ~ hongjiang
# Processing data for City 277 ~ olds
# phan rang not found, moving on!
# Processing data for City 278 ~ dhari
# Processing data for City 279 ~ constitucion
# Processing data for City 280 ~ lanxi
# Processing data for City 281 ~ dalbandin
# Processing data for City 282 ~ san severino marche
# Processing data for City 283 ~ susanville
# tsienyane not found, moving on!
# Processing data for City 284 ~ estrela
# Processing data for City 285 ~ ginir
# Processing data for City 286 ~ zhovtneve
# Processing data for City 287 ~ thaba nchu
# Processing data for City 288 ~ bhera
# Processing data for City 289 ~ kiama
# Processing data for City 290 ~ paamiut
# Processing data for City 291 ~ nyurba
# Processing data for City 292 ~ awjilah
# Processing data for City 293 ~ leopold
# Processing data for City 294 ~ husavik
# Processing data for City 295 ~ te anau
# Processing data for City 296 ~ faanui
# Processing data for City 297 ~ moron
# Processing data for City 298 ~ faya
# Processing data for City 299 ~ vanimo
# Processing data for City 300 ~ morgan hill
# Processing data for City 301 ~ esperance
# Processing data for City 302 ~ ejea de los caballeros
# Processing data for City 303 ~ tuatapere
# Processing data for City 304 ~ hun
# Processing data for City 305 ~ emerald
# Processing data for City 306 ~ minot
# Processing data for City 307 ~ samoylovka
# Processing data for City 308 ~ ukiah
# Processing data for City 309 ~ luanda
# Processing data for City 310 ~ gat
# Processing data for City 311 ~ prince rupert
# Processing data for City 312 ~ pathein
# Processing data for City 313 ~ olinda
# Processing data for City 314 ~ luena
# Processing data for City 315 ~ waipawa
# Processing data for City 316 ~ beaupre
# Processing data for City 317 ~ byron bay
# Processing data for City 318 ~ tefe
# Processing data for City 319 ~ vao
# Processing data for City 320 ~ halifax
# Processing data for City 321 ~ saryg-sep
# Processing data for City 322 ~ port macquarie
# Processing data for City 323 ~ siocon
# Processing data for City 324 ~ kahului
# Processing data for City 325 ~ san fernando
# Processing data for City 326 ~ farmington
# louisbourg not found, moving on!
# Processing data for City 327 ~ gazojak
# Processing data for City 328 ~ sanmenxia
# Processing data for City 329 ~ ocos
# Processing data for City 330 ~ ostrovnoy
# Processing data for City 331 ~ qaqortoq
# Processing data for City 332 ~ rocha
# himora not found, moving on!
# Processing data for City 333 ~ la paz
# labutta not found, moving on!
# Processing data for City 334 ~ buta
# Processing data for City 335 ~ aguimes
# Processing data for City 336 ~ sorland
# Processing data for City 337 ~ roseburg
# Processing data for City 338 ~ mezhdurechensk
# Processing data for City 339 ~ nyborg
# Processing data for City 340 ~ bengkulu
# Processing data for City 341 ~ mangrol
# Processing data for City 342 ~ plettenberg bay
# Processing data for City 343 ~ kualakapuas
# Processing data for City 344 ~ gillette
# Processing data for City 345 ~ alice springs
# Processing data for City 346 ~ merritt
# Processing data for City 347 ~ raga
# Processing data for City 348 ~ leningradskiy
# Processing data for City 349 ~ port augusta
# Processing data for City 350 ~ vizinga
# Processing data for City 351 ~ aldan
# Processing data for City 352 ~ grand gaube
# Processing data for City 353 ~ lokoja
# Processing data for City 354 ~ bayonet point
# Processing data for City 355 ~ sao jose da coroa grande
# Processing data for City 356 ~ buala
# Processing data for City 357 ~ richards bay
# Processing data for City 358 ~ ismailia
# Processing data for City 359 ~ tasiilaq
# Processing data for City 360 ~ riyadh
# Processing data for City 361 ~ yulara
# Processing data for City 362 ~ half moon bay
# Processing data for City 363 ~ orchard homes
# Processing data for City 364 ~ touros
# formoso do araguaia not found, moving on!
# Processing data for City 365 ~ maragogi
# Processing data for City 366 ~ rovaniemi
# play cu not found, moving on!
# Processing data for City 367 ~ mabama
# Processing data for City 368 ~ coihaique
# Processing data for City 369 ~ vestmanna
# Processing data for City 370 ~ nishihara
# tlaxiaco not found, moving on!
# Processing data for City 371 ~ lae
# Processing data for City 372 ~ gamba
# Processing data for City 373 ~ porto novo
# Processing data for City 374 ~ meulaboh
# Processing data for City 375 ~ khani
# Processing data for City 376 ~ namibe
# Processing data for City 377 ~ west wendover
# Processing data for City 378 ~ yongchang
# Processing data for City 379 ~ lavrentiya
# Processing data for City 380 ~ atar
# Processing data for City 381 ~ sorong
# Processing data for City 382 ~ muisne
# kamenskoye not found, moving on!
# Processing data for City 383 ~ neuquen
# Processing data for City 384 ~ fairbanks
# Processing data for City 385 ~ bay roberts
# Processing data for City 386 ~ seddon
# Processing data for City 387 ~ shilka
# Processing data for City 388 ~ pevek
# Processing data for City 389 ~ kabalo
# Processing data for City 390 ~ gejiu
# Processing data for City 391 ~ airai
# Processing data for City 392 ~ pangody
# Processing data for City 393 ~ sumbawanga
# Processing data for City 394 ~ birao
# Processing data for City 395 ~ manadhoo
# Processing data for City 396 ~ keshorai patan
# Processing data for City 397 ~ la rioja
# Processing data for City 398 ~ vardo
# Processing data for City 399 ~ basco
# Processing data for City 400 ~ honningsvag
# Processing data for City 401 ~ dudinka
# bargal not found, moving on!
# Processing data for City 402 ~ karratha
# Processing data for City 403 ~ cam ranh
# Processing data for City 404 ~ leshukonskoye
# Processing data for City 405 ~ manta
# vaitupu not found, moving on!
# Processing data for City 406 ~ patea
# Processing data for City 407 ~ guane
# Processing data for City 408 ~ kenai
# yirol not found, moving on!
# Processing data for City 409 ~ moissala
# Processing data for City 410 ~ lingao
# Processing data for City 411 ~ ust-tsilma
# Processing data for City 412 ~ dobsina
# satitoa not found, moving on!
# Processing data for City 413 ~ antalaha
# Processing data for City 414 ~ bilma
# mergui not found, moving on!
# Processing data for City 415 ~ sesheke
# Processing data for City 416 ~ pisco
# cazaje not found, moving on!
# Processing data for City 417 ~ deputatskiy
# mullaitivu not found, moving on!
# Processing data for City 418 ~ laguna
# umm jarr not found, moving on!
# Processing data for City 419 ~ zinder
# rungata not found, moving on!
# Processing data for City 420 ~ vestmannaeyjar
# Processing data for City 421 ~ belyy yar
# Processing data for City 422 ~ general roca
# Processing data for City 423 ~ kichera
# Processing data for City 424 ~ colares
# Processing data for City 425 ~ axim
# Processing data for City 426 ~ tilichiki
# okandja not found, moving on!
# Processing data for City 427 ~ vila velha
# Processing data for City 428 ~ kanbe
# Processing data for City 429 ~ mbandaka
# Processing data for City 430 ~ kaohsiung
# Processing data for City 431 ~ qianan
# Processing data for City 432 ~ villarrica
# Processing data for City 433 ~ calabar
# Processing data for City 434 ~ hamilton
# Processing data for City 435 ~ barsi
# kadykchan not found, moving on!
# Processing data for City 436 ~ fiumicino
# Processing data for City 437 ~ shenjiamen
# Processing data for City 438 ~ baraya
# Processing data for City 439 ~ saint-francois
# Processing data for City 440 ~ yaring
# Processing data for City 441 ~ poya
# Processing data for City 442 ~ akureyri
# Processing data for City 443 ~ mozarlandia
# Processing data for City 444 ~ kuching
# Processing data for City 445 ~ eureka
# Processing data for City 446 ~ bereda
# Processing data for City 447 ~ cameta
# Processing data for City 448 ~ lufilufi
# Processing data for City 449 ~ eyl
# Processing data for City 450 ~ alhadas
# Processing data for City 451 ~ klyuchi
# Processing data for City 452 ~ kavaratti
# ozgon not found, moving on!
# Processing data for City 453 ~ kiunga
# Processing data for City 454 ~ igarka
# Processing data for City 455 ~ lappeenranta
# Processing data for City 456 ~ dhidhdhoo
# Processing data for City 457 ~ souillac
# Processing data for City 458 ~ kungurtug
# Processing data for City 459 ~ taylorville
# Processing data for City 460 ~ newtownards
# cockburn harbour not found, moving on!
# Processing data for City 461 ~ cherdyn
# Processing data for City 462 ~ dossor
# Processing data for City 463 ~ khandyga
# Processing data for City 464 ~ pipraich
# Processing data for City 465 ~ ugoofaaru
# Processing data for City 466 ~ jaciara
# tabiauea not found, moving on!
# Processing data for City 467 ~ kirkenes
# Processing data for City 468 ~ matay
# Processing data for City 469 ~ lasa
# Processing data for City 470 ~ college
# Processing data for City 471 ~ udachnyy
# Processing data for City 472 ~ gold coast
# Processing data for City 473 ~ ponta delgada
# Processing data for City 474 ~ turbat
# Processing data for City 475 ~ imbituba
# Processing data for City 476 ~ urumqi
# Processing data for City 477 ~ scarborough
# Processing data for City 478 ~ birjand
# Processing data for City 479 ~ magistralnyy
# Processing data for City 480 ~ baoning
# Processing data for City 481 ~ iwanai
# Processing data for City 482 ~ say
# Processing data for City 483 ~ guye
# kilmez not found, moving on!
# Processing data for City 484 ~ williston
# assela not found, moving on!
# Processing data for City 485 ~ muros
# Processing data for City 486 ~ leh
# Processing data for City 487 ~ goderich
# Processing data for City 488 ~ walvis bay
# Processing data for City 489 ~ boljevac
# Processing data for City 490 ~ tabou
# Processing data for City 491 ~ palm coast
# Processing data for City 492 ~ la macarena
# Processing data for City 493 ~ raudeberg
# Processing data for City 494 ~ sibolga
# Processing data for City 495 ~ hirna
# Processing data for City 496 ~ tuxpan
# Processing data for City 497 ~ floro
# Processing data for City 498 ~ derac
# Processing data for City 499 ~ ketchikan
# Processing data for City 500 ~ gyonk

# %%
# create a dataframe in which to place all API data that was gathered. 
# list is used to gather each dataset that was grabbed from API. put each list together with titles for the dataframe
weather2 = {
    "City": cityname,
    "Cloudiness": cloudiness, 
    "Country": countryname,
    "Date": date, 
    "Humidity": humidity,
    "Latitude": latitude, 
    "Longitude": longitude, 
    "Max Temp": maxtemp,
    "Wind Speed":windspeed
}

# create a dataframe from the lists of info, will be the columns
# show the count of cities, should be 500 total
weather_df_2 = pd.DataFrame(weather2)
weather_df_2.count()
# Out:
# City          500
# Cloudiness    500
# Country       500
# Date          500
# Humidity      500
# Latitude      500
# Longitude     500
# Max Temp      500
# Wind Speed    500
# dtype: int64

# %%
weather_df_2.to_csv(output_data_file_2nd)
# export the new dataframe with all cities to a csv
weather_df_2.head()
# Out:
#            City  Cloudiness Country        Date  Humidity  Latitude  \
# 0  Fergus Falls           1      US  1593217018        44     46.28
# 1  Marsá Maţrūḩ           0      EG  1593217245        82     31.35
# 2   Pangnirtung          17      CA  1593217246        63     66.15
# 3      Tamiahua          82      MX  1593217248        79     21.27
# 4      Hermanus          19      ZA  1593217249        87    -34.42
#
#    Longitude  Max Temp  Wind Speed
# 0     -96.08    300.37        2.10
# 1      27.25    295.61        3.99
# 2     -65.71    284.34        1.08
# 3     -97.45    301.55        6.43
# 4      19.23    284.82        6.26

# %% [markdown]
# ## Plotting the Data

# %%
area = (30 * np.random.rand(len(weather_df_2)))**2
colors = np.random.rand(len(weather_df_2))
# randomize the colors for each city when displayed in a plot

# %% [markdown]
# #### Latitude vs Temperature Plot

# %%
plt.figure(figsize=(10, 8))
plt.scatter(weather_df_2["Latitude"], weather_df_2["Max Temp"], marker="o", s=area, c=colors, alpha=0.5)
# choose the proper columns from the dataframe when creating the plot
plt.title(f"Latitude Vs Temperature ({time.strftime('%x')})")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.tight_layout()
plt.savefig("LatitudeVsTemperature_2.png")
plt.show()

# %% [markdown]
# #### Latitude vs Humidity Plot

# %%
plt.figure(figsize=(10, 8))
plt.scatter(weather_df_2["Latitude"], weather_df_2["Humidity"], marker="o", s=area, c=colors, alpha=0.5)
plt.title(f"Latitude Vs Humidity ({time.strftime('%x')})")
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.ylim(0, 100)
plt.grid(True)


plt.tight_layout()
plt.savefig("LatitudeVsHumidity_2.png")
plt.show()

# %% [markdown]
# #### Latitude vs Cloudiness Plot

# %%
plt.figure(figsize=(10, 8))
plt.scatter(weather_df_2["Latitude"], weather_df_2["Cloudiness"], marker="o", s=area, c=colors, alpha=0.5)
plt.title(f"Latitude Vs Cloudiness ({time.strftime('%x')})")
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.tight_layout()
plt.savefig("LatitudeVsCloudiness_2.png")
plt.show()

# %% [markdown]
# #### Latitude vs Wind Speed Plot

# %%
plt.figure(figsize=(10, 8))
plt.scatter(weather_df_2["Latitude"], weather_df_2["Wind Speed"], marker="o", s=area, c=colors, alpha=0.5)
plt.title(f"Latitude Vs Wind Speed ({time.strftime('%x')})")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.tight_layout()
plt.savefig("LatitudeVsWindSpeed_2.png")
plt.show()
